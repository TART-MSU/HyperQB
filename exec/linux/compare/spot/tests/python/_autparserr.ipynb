# %%
from IPython.display import display
import spot
spot.setup()

# %% [markdown]
# Test syntax errors
# ------------------

# %%
# %%file _example.aut
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [t] 1
# State: 1
# [t] 1
# --END--
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [a] 3
# State: 1
# [1] 0
# [0&!1] 1
# --END--
# Out:
# Writing _example.aut

# %%
for a in spot.automata('_example.aut'):
    display(a)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f695c599f50> >
# Traceback (most recent call last):
#
#   File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     for a in spot.automata('_example.aut'):
#
#   File ~/git/spot/python/spot/__init__.py:718 in automata
#     res = p.parse(_bdd_dict)
#
#   File <string>
# SyntaxError:
# _example.aut:20.2: syntax error, unexpected identifier
# _example.aut:20.1-3: ignoring this invalid label
# _example.aut:20.5: state number is larger than state count...
# _example.aut:14.1-9: ... declared here.

# %%
spot.automaton('_example.aut', timeout=100)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f695c59a370> >

# %% [markdown]
# # Error reading from pipe
#
# We redirect stderr to /dev/null to avoid difference between ipykernel 5 (that sends stderr to the console) and ipykernel 6 (that captures stderr for the notebook).

# %%
spot.automaton('non-existing-cmd 2>/dev/null |')
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 spot.automaton('non-existing-cmd 2>/dev/null |')
#
# File ~/git/spot/python/spot/__init__.py:747, in automaton(filename, **kwargs)
#     743 """Read a single automaton from a file.
#     744
#     745 See `spot.automata` for a list of supported formats."""
#     746 try:
# --> 747     return next(automata(filename, **kwargs))
#     748 except StopIteration:
#     749     raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# File ~/git/spot/python/spot/__init__.py:732, in automata(timeout, ignore_abort, trust_hoa, no_sid, debug, want_kripke, drop_false_edges, *sources)
#     729             # Do not complain about the exit code if we are already raising
#     730             # an exception.
#     731             if ret and sys.exc_info()[0] is None:
# ...

# %%
spot.automaton('sleep 3; cat _example.aut |', timeout=1)
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spot.automaton('sleep 3; cat _example.aut |', timeout=1)
#
# File ~/git/spot/python/spot/__init__.py:747, in automaton(filename, **kwargs)
#     743 """Read a single automaton from a file.
#     744
#     745 See `spot.automata` for a list of supported formats."""
#     746 try:
# --> 747     return next(automata(filename, **kwargs))
#     748 except StopIteration:
#     749     raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# File ~/git/spot/python/spot/__init__.py:687, in automata(timeout, ignore_abort, trust_hoa, no_sid, debug, want_kripke, drop_false_edges, *sources)
#     685 else:
#     686     try:
# --> 687         out, err = proc.communicate(timeout=timeout)
#     688     except subprocess.TimeoutExpired:
# ...

# %%
for a in spot.automata("ltl2tgba 'a U b'|", 'ltl2tgba "syntax U U error" 2>/dev/null |'):
    display(a)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6945207210> >
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for a in spot.automata("ltl2tgba 'a U b'|", 'ltl2tgba "syntax U U error" 2>/dev/null |'):
#       2     display(a)
#
# File ~/git/spot/python/spot/__init__.py:732, in automata(timeout, ignore_abort, trust_hoa, no_sid, debug, want_kripke, drop_false_edges, *sources)
#     729             # Do not complain about the exit code if we are already raising
#     730             # an exception.
#     731             if ret and sys.exc_info()[0] is None:
# --> 732                 raise subprocess.CalledProcessError(ret, filename[:-1])
#     733 # deleting o explicitly now prevents Python 3.5 from
#     734 # reporting the following error: "<built-in function
# ...

# %% [markdown]
# Reading an empty file with `spot.automaton()` is an error.

# %%
spot.automaton('true|')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/git/spot/python/spot/__init__.py:747, in automaton(filename, **kwargs)
#     746 try:
# --> 747     return next(automata(filename, **kwargs))
#     748 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spot.automaton('true|')
#
# File ~/git/spot/python/spot/__init__.py:749, in automaton(filename, **kwargs)
#     747     return next(automata(filename, **kwargs))
#     748 except StopIteration:
# --> 749     raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# RuntimeError: Failed to read automaton from true|

# %%
# !rm _example.aut
